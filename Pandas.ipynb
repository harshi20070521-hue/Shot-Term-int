# %% [markdown]
# # Pandas Basics Notebook

# %% [markdown]
# #### 1.What is pandas?

# %% [markdown]
# **Definition**: pandas is python lib used for data cleaning ,analysis and manipulation.
#
# - works like excel bit faster
# - helps load, clean, filter, analyze data
# - uses:data science ,machine learning, finance, analytics, and automating data task.

# %% [markdown]
# # import pandas

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ### Pandas data structures

# %% [markdown]
# **Series**-> One dimensional column
#
# **Dataframe**->tab;le with rows +columns

# %%
o=pd.Series([10,20,30])
o
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
df=pd.DataFrame({
    "name":["Uma","Renuka"],
    "age":[32,65]
})
df
# Out:
#      name  age
# 0     Uma   32
# 1  Renuka   65

# %%
data={
    "domain":["AI","ML","DS"],
    "trainer_name":["pavan","mani","harsha"],
}
data
# Out:
# {'domain': ['AI', 'ML', 'DS'], 'trainer_name': ['pavan', 'mani', 'harsha']}

# %%
df=pd.DataFrame(data)
df
# Out:
#   domain trainer_name
# 0     AI        pavan
# 1     ML         mani
# 2     DS       harsha

# %% [markdown]
# # Reading Data(csv)

# %%
df=pd.read_csv(r"C:\Users\harsh\Downloads\cleaned_car_price_dataset.csv")
df
# Out:
#     Car_Name  Year  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0      Car_0  2011          14.91       66476    Petrol      Dealer
# 1      Car_1  2019          17.39       49811    Diesel  Individual
# 2      Car_2  2015          17.56       76180    Petrol      Dealer
# 3      Car_3  2012           9.88      117856       CNG      Dealer
# 4      Car_4  2011          18.09       73450    Diesel      Dealer
# ..       ...   ...            ...         ...       ...         ...
# 195  Car_195  2009          15.44       11949    Diesel  Individual
# 196  Car_196  2009           5.17       60393    Diesel  Individual
# 197  Car_197  2013           7.25      143013    Petrol  Individual
# 198  Car_198  2013          12.87       30934    Diesel  Individual
# 199  Car_199  2007          17.74       80745       CNG  Individual
#
#     Transmission  Owner  Selling_Price
# 0         Manual      1           7.16
# 1      Automatic      2           9.98
# ...

# %%
df=pd.read_csv(r"C:\Users\harsh\Downloads\weather_dataset_2025.csv")
df
# Out:
#             Date       City  Temperature_C  Humidity_%  Wind_Speed_km_h  \
# 0     2025-01-01     Riyadh           15.8          94             21.0
# 1     2025-01-01     Jeddah           31.5          54             25.3
# 2     2025-01-01     Dammam           30.4          33              8.6
# 3     2025-01-01      Dubai           34.0          37             18.7
# 4     2025-01-01       Doha           28.3          32              6.8
# ...          ...        ...            ...         ...              ...
# 5470  2025-12-31     Sydney           33.5          71             22.9
# 5471  2025-12-31    Toronto            9.1          43             37.4
# 5472  2025-12-31     Berlin            6.3          42             23.7
# 5473  2025-12-31     Mumbai           27.6          58             12.5
# 5474  2025-12-31  Singapore           44.3          75              4.6
#
#       Precipitation_mm      Condition
# 0                 0.00         Cloudy
# ...

# %% [markdown]
# # Reading data(Excel)

# %%
df=pd.read_excel(r"C:\Users\harsh\Downloads\weather_dataset_kaggle.xlsx")
df
# Out:
#            Date   City  Temperature_C  Humidity_%  WindSpeed_kmh  Rainfall_mm  \
# 0    2025-01-02  Abuja           35.9          97            8.7         29.6
# 1    2025-01-03  Abuja           27.0          49           23.6          5.0
# 2    2025-01-04  Abuja           18.6          46           20.6        116.1
# 3    2025-01-05   Kano           27.7          83           32.6        100.7
# 4    2025-01-06  Lagos           23.7          87           28.8         56.8
# ..          ...    ...            ...         ...            ...          ...
# 495  2026-05-12   Kano           33.9          62           16.0         78.6
# 496  2026-05-13  Lagos           19.3          94            2.3        112.6
# 497  2026-05-14  Abuja           29.4          87           20.6        120.0
# 498  2026-05-15   Kano           31.4          71           14.6         85.4
# 499  2026-05-16  Lagos           23.8          90           12.9        101.8
#
# ...

# %% [markdown]
# # Writting the data into files

# %%
df.to_csv('data.csv',index=False)

# %%
df.to_excel('new.xlsx', sheet_nmae='weather_data',index=False)

# %% [markdown]
# ## Exploring data

# %%
df.head()
# Out:
#          Date   City  Temperature_C  Humidity_%  WindSpeed_kmh  Rainfall_mm  \
# 0  2025-01-02  Abuja           35.9          97            8.7         29.6
# 1  2025-01-03  Abuja           27.0          49           23.6          5.0
# 2  2025-01-04  Abuja           18.6          46           20.6        116.1
# 3  2025-01-05   Kano           27.7          83           32.6        100.7
# 4  2025-01-06  Lagos           23.7          87           28.8         56.8
#
#    Pressure_hPa Weather_Condition  UV_Index
# 0          1028             Rainy         4
# 1           992             Sunny         3
# 2          1003            Stormy        10
# 3           996            Cloudy        11
# 4          1026             Windy         4

# %%
df.head(2)
# Out:
#          Date   City  Temperature_C  Humidity_%  WindSpeed_kmh  Rainfall_mm  \
# 0  2025-01-02  Abuja           35.9          97            8.7         29.6
# 1  2025-01-03  Abuja           27.0          49           23.6          5.0
#
#    Pressure_hPa Weather_Condition  UV_Index
# 0          1028             Rainy         4
# 1           992             Sunny         3

# %%
df.tail()
# Out:
#            Date   City  Temperature_C  Humidity_%  WindSpeed_kmh  Rainfall_mm  \
# 495  2026-05-12   Kano           33.9          62           16.0         78.6
# 496  2026-05-13  Lagos           19.3          94            2.3        112.6
# 497  2026-05-14  Abuja           29.4          87           20.6        120.0
# 498  2026-05-15   Kano           31.4          71           14.6         85.4
# 499  2026-05-16  Lagos           23.8          90           12.9        101.8
#
#      Pressure_hPa Weather_Condition  UV_Index
# 495          1017            Stormy        11
# 496           998             Windy         5
# 497          1023             Windy         6
# 498          1017             Windy         1
# 499           987             Sunny         9

# %%
df.tail(3)
# Out:
#            Date   City  Temperature_C  Humidity_%  WindSpeed_kmh  Rainfall_mm  \
# 497  2026-05-14  Abuja           29.4          87           20.6        120.0
# 498  2026-05-15   Kano           31.4          71           14.6         85.4
# 499  2026-05-16  Lagos           23.8          90           12.9        101.8
#
#      Pressure_hPa Weather_Condition  UV_Index
# 497          1023             Windy         6
# 498          1017             Windy         1
# 499           987             Sunny         9

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               500 non-null    str
#  1   City               500 non-null    str
#  2   Temperature_C      500 non-null    float64
#  3   Humidity_%         500 non-null    int64
#  4   WindSpeed_kmh      500 non-null    float64
#  5   Rainfall_mm        500 non-null    float64
#  6   Pressure_hPa       500 non-null    int64
#  7   Weather_Condition  500 non-null    str
#  8   UV_Index           500 non-null    int64
# dtypes: float64(3), int64(3), str(3)
# memory usage: 35.3 KB

# %%
df['Date']
# Out:
# 0      2025-01-02
# 1      2025-01-03
# 2      2025-01-04
# 3      2025-01-05
# 4      2025-01-06
#           ...
# 495    2026-05-12
# 496    2026-05-13
# 497    2026-05-14
# 498    2026-05-15
# 499    2026-05-16
# Name: Date, Length: 500, dtype: str

# %%
df.Date
# Out:
# 0      2025-01-02
# 1      2025-01-03
# 2      2025-01-04
# 3      2025-01-05
# 4      2025-01-06
#           ...
# 495    2026-05-12
# 496    2026-05-13
# 497    2026-05-14
# 498    2026-05-15
# 499    2026-05-16
# Name: Date, Length: 500, dtype: str

# %%
df['Date'][df['Weather_Condition']=='Rainy']
# Out:
# 0      2025-01-02
# 5      2025-01-07
# 10     2025-01-12
# 19     2025-01-21
# 27     2025-01-29
#           ...
# 440    2026-03-18
# 445    2026-03-23
# 459    2026-04-06
# 479    2026-04-26
# 490    2026-05-07
# Name: Date, Length: 95, dtype: str

# %%
df.shape
# Out:
# (500, 9)

# %%
df[4:90]
# Out:
#           Date           City  Temperature_C  Humidity_%  WindSpeed_kmh  \
# 4   2025-01-06          Lagos           23.7          87           28.8
# 5   2025-01-07  Port Harcourt           32.4          52           12.7
# 6   2025-01-08          Abuja           35.1          51           10.8
# 7   2025-01-09          Abuja           19.4          66            3.6
# 8   2025-01-10  Port Harcourt           35.0          69           18.8
# ..         ...            ...            ...         ...            ...
# 85  2025-03-28  Port Harcourt           29.1          43           15.9
# 86  2025-03-29           Kano           25.6          70           11.4
# 87  2025-03-30           Kano           33.5          93           24.9
# 88  2025-03-31          Abuja           26.3          97           21.9
# 89  2025-04-01  Port Harcourt           28.2          77           11.6
#
#     Rainfall_mm  Pressure_hPa Weather_Condition  UV_Index
# ...

# %%
df.columns
# Out:
# Index(['Date', 'City', 'Temperature_C', 'Humidity_%', 'WindSpeed_kmh',
#        'Rainfall_mm', 'Pressure_hPa', 'Weather_Condition', 'UV_Index'],
#       dtype='str')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
df.dtypes
# Out:
# Date                     str
# City                     str
# Temperature_C        float64
# Humidity_%             int64
# WindSpeed_kmh        float64
# Rainfall_mm          float64
# Pressure_hPa           int64
# Weather_Condition        str
# UV_Index               int64
# dtype: object

# %%
df[['Date','Weather_Condition']]
# Out:
#            Date Weather_Condition
# 0    2025-01-02             Rainy
# 1    2025-01-03             Sunny
# 2    2025-01-04            Stormy
# 3    2025-01-05            Cloudy
# 4    2025-01-06             Windy
# ..          ...               ...
# 495  2026-05-12            Stormy
# 496  2026-05-13             Windy
# 497  2026-05-14             Windy
# 498  2026-05-15             Windy
# 499  2026-05-16             Sunny
#
# [500 rows x 2 columns]

# %%
df.Temperature_C
# Out:
# 0      35.9
# 1      27.0
# 2      18.6
# 3      27.7
# 4      23.7
#        ...
# 495    33.9
# 496    19.3
# 497    29.4
# 498    31.4
# 499    23.8
# Name: Temperature_C, Length: 500, dtype: float64
